# %% [markdown]
# # Databricks Delta
# #### Load a CSV file

# %%
PATH = '/mnt/rawdata/UsedCars.csv'

used_cars = spark.read.option("header", "true").csv(PATH)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(used_cars)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Price</th><th>Age</th><th>KM</th><th>FuelType</th><th>HP</th><th>MetColor</th><th>Automatic</th><th>CC</th><th>Doors</th><th>Weight</th></tr></thead><tbody><tr><td>7450.0</td><td>65.0</td><td>82000.0</td><td>Petrol</td><td>86</td><td>1</td><td>0</td><td>1300</td><td>3</td><td>1015</td></tr><tr><td>7250.0</td><td>74.0</td><td>130025.0</td><td>Petrol</td><td>110</td><td>1</td><td>0</td><td>1600</td><td>3</td><td>1050</td></tr><tr><td>8950.0</td><td>80.0</td><td>64000.0</td><td>Petrol</td><td>110</td><td>0</td><td>0</td><td>1600</td><td>3</td><td>1055</td></tr><tr><td>11450.0</td><td>54.0</td><td>62987.0</td><td>Petrol</td><td>110</td><td>0</td><td>0</td><td>1600</td><td>5</td><td>1080</td></tr><tr><td>null</td><td>42.0</td><td>38932.0</td><td>Petrol</td><td>110</td><td>1</td><td>0</td><td>1600</td><td>3</td><td>1040</td></tr><tr><td>6950.0</td><td>80.0</td><td>62581.0</td><td>Petrol</td><td>110</td><td>0</td><td>0</td><td>1600</td><td>5</td><td>1075</td></tr><tr><td>8250.0</td><td>70.0</td><td>59017.0</td><td>petrol</td><td>107</td><td>1</td><td>1</td><td>1600</td><td>3</td><td>1080</td></tr><tr><td>12950.0</td><td>44.0</td><td>41499.0</td><td>CNG</td><td>110</td><td>1</td><td>0</td><td>1600</td><td>5</td><td>1103</td></tr><tr><td>9950.0</td><td>65.0</td><td>65513.0</td><td>Petrol</td><td>110</td><td>1</td><td>1</td><td>1600</td><td>4</td><td>1070</td></tr><tr><td>7900.0</td><td>75.0</td><td>125400.0</td><td>Petrol</td><td>110</td><td>0</td><td>0</td><td>1600</td><td>3</td><td>1050</td></tr><tr><td>6495.0</td><td>74.0</td><td>96302.0</td><td>Petrol</td><td>86</td><td>1</td><td>0</td><td>1300</td><td>3</td><td>1015</td></tr><tr><td>9500.0</td><td>66.0</td><td>74963.0</td><td>Petrol</td><td>107</td><td>0</td><td>1</td><td>1600</td><td>3</td><td>1085</td></tr><tr><td>6490.0</td><td>80.0</td><td>100123.0</td><td>Petrol</td><td>110</td><td>1</td><td>0</td><td>1600</td><td>3</td><td>1050</td></tr><tr><td>7250.0</td><td>80.0</td><td>110887.0</td><td>Petrol</td><td>110</td><td>1</td><td>0</td><td>1600</td><td>3</td><td>1055</td></tr><tr><td>9450.0</td><td>80.0</td><td>66843.0</td><td>petrol</td><td>110</td><td>1</td><td>0</td><td>1600</td><td>5</td><td>1075</td></tr><tr><td>16500.0</td><td>27.0</td><td>37177.0</td><td>Petrol</td><td>110</td><td>0</td><td>0</td><td>1600</td><td>5</td><td>1130</td></tr><tr><td>9250.0</td><td>63.0</td><td>102807.0</td><td>Petrol</td><td>86</td><td>0</td><td>0</td><td>1300</td><td>5</td><td>1055</td></tr><tr><td>6900.0</td><td>69.0</td><td>146304.0</td><td>Diesel</td><td>72</td><td>1</td><td>0</td><td>2000</td><td>3</td><td>1115</td></tr><tr><td>11950.0</td><td>56.0</td><td>33998.0</td><td>Petrol</td><td>110</td><td>0</td><td>0</td><td>1600</td><td>5</td><td>1080</td></tr><tr><td>9950.0</td><td>61.0</td><td>97425.0</td><td>Petrol</td><td>110</td><td>1</td><td>0</td><td>1600</td><td>5</td><td>1075</td></tr><tr><td>8450.0</td><td>69.0</td><td>74573.0</td><td>Petrol</td><td>110</td><td>1</td><td>0</td><td>1600</td><td>5</td><td>1085</td></tr><tr><td>9950.0</td><td>63.0</td><td>57000.0</td><td>Petrol</td><td>86</td><td>1</td><td>0</td><td>1300</td><td>5</td><td>1035</td></tr><tr><td>13500.0</td><td>43.0</td><td>10000.0</td><td>petrol</td><td>97</td><td>1</td><td>0</td><td>1400</td><td>5</td><td>1060</td></tr><tr><td>8950.0</td><td>75.0</td><td>102005.0</td><td>Petrol</td><td>107</td><td>1</td><td>1</td><td>1600</td><td>5</td><td>1105</td></tr><tr><td>7750.0</td><td>74.0</td><td>78894.0</td><td>petrol</td><td>110</td><td>0</td><td>0</td><td>1600</td><td>5</td><td>1070</td></tr><tr><td>10500.0</td><td>78.0</td><td>47400.0</td><td>Petrol</td><td>86</td><td>1</td><td>0</td><td>1300</td><td>5</td><td>1040</td></tr><tr><td>8950.0</td><td>72.0</td><td>75525.0</td><td>Petrol</td><td>110</td><td>1</td><td>0</td><td>1600</td><td>3</td><td>1114</td></tr><tr><td>8500.0</td><td>78.0</td><td>90345.0</td><td> ...

# %% [markdown]
# ## Persist in Delta format

# %%
used_cars.write.mode("overwrite").format("delta").save("/delta/{}".format(file_name), )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dbutils.fs.ls("dbfs:/delta/{}".format(file_name)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/delta/UsedCars/_delta_log/</td><td>_delta_log/</td><td>0</td></tr><tr><td>dbfs:

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [Table(name=&#39;used_cars&#39;, database=&#39;default&#39;, description=None, tableType=&#39;EXTERNAL&#39;, isTemporary=False),
#  Table(name=&#39;used_cars_by_fuel_type&#39;, database=&#39;default&#39;, description=None, tableType=&#39;EXTERNAL&#39;, isTemporary=False),
#  Table(name=&#39;usedcars_managed&#39;, database=&#39;default&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False),
#  Table(name=&#39;usedcars_unmanaged&#39;, database=&#39;default&#39;, description=None, tableType=&#39;EXTERNAL&#39;, isTemporary=False)]</div>

# %% [markdown]
# ## Split by partition
# Use Fuel Type to split in partitions (performance)

# %%
file_name_by_partition = "UsedCars_by_fuel_type"

used_cars.write.mode("overwrite").partitionBy("FuelType").format("delta").save("/delta/{}".format(file_name_by_partition))
spark.sql("CREATE TABLE used_cars_by_fuel_type USING DELTA LOCATION '/delta/{}/'".format(file_name_by_partition))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: DataFrame[]</div>

# %%
display(dbutils.fs.ls("dbfs:/delta"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/delta/UsedCars/</td><td>UsedCars/</td><td>0</td></tr><tr><td>dbfs:/delta/UsedCars_by_fuel_type/</td><td>UsedCars_by_fuel_type/</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
SELECT FuelType, COUNT(*) FROM used_cars_by_fuel_type GROUP BY FuelType
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>FuelType</th><th>count(1)</th></tr></thead><tbody><tr><td>Diesel</td><td>147</td></tr><tr><td>diesel</td><td>10</td></tr><tr><td>petrol</td><td>199</td></tr><tr><td>CNG</td><td>9</td></tr><tr><td>methane</td><td>4</td></tr><tr><td>Petrol</td><td>1073</td></tr><tr><td>CompressedNaturalGas</td><td>4</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE DETAIL used_cars_by_fuel_type
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>597dbe3f-fe82-4f16-9889-0d95939c4087</td><td>default.used_cars_by_fuel_type</td><td>null</td><td>dbfs:/delta/UsedCars_by_fuel_type</td><td>2020-06-18T19:48:44.844+0000</td><td>2020-06-18T19:48:47.000+0000</td><td>List(FuelType)</td><td>7</td><td>32908</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# ## Time Travel
# Because Delta Lake is version controlled, you have the option to query past versions of the data. Let's look at the history of our current Delta table.

# %%
# %sql
DESCRIBE HISTORY used_cars
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th></tr></thead><tbody><tr><td>2</td><td>2020-06-18T19:58:33.000+0000</td><td>2671230428599712</td><td>lubraz@microsoft.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(3418276086377984)</td><td>0618-190813-trues609</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputBytes -> 2301, numOutputRows -> 1)</td></tr><tr><td>1</td><td>2020-06-18T19:48:06.000+0000</td><td>2671230428599712</td><td>lubraz@microsoft.com</td><td>WRITE</td><td>Map(mode -> Overwrite, partitionBy -> [])</td><td>null</td><td>List(3418276086377984)</td><td>0618-190813-trues609</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numOutputBytes -> 19347, numOutputRows -> 1446)</td></tr><tr><td>0</td><td>2020-06-18T19:32:09.000+0000</td><td>2671230428599712</td><td>lubraz@microsoft.com</td><td>WRITE</td><td>Map(mode -> Overwrite, partitionBy -> [])</td><td>null</td><td>List(3418276086377984)</td><td>0618-190813-trues609</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numOutputBytes -> 19347, numOutputRows -> 1446)</td></tr></tbody></table></div>

# %% [markdown]
# ### Insert a new row

# %%
# %sql
INSERT INTO used_cars
SELECT 5500, 44, 34000, 'Petrol', 110, 1, 1, 1300, 3, 1005
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Querying an older version is as easy as adding `VERSION AS OF desired_version`. Let's verify that our table from one version back still exists.

# %%
# %sql
SELECT count(*)
FROM used_cars
VERSION AS OF 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1447</td></tr></tbody></table></div>

# %% [markdown]
# ### Delete Delta

# %%
dbutils.fs.rm("/delta/", True)
